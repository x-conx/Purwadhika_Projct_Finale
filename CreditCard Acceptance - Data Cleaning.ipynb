# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # read csv file

# %%
df = pd.read_csv('creditcardmarketing-bbm.csv')

# %%
df
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %% [markdown]
# # cleaning null data

# %%
df[df.isna().any(axis=1)]
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 323                324             No     Points    Postcard       Medium
# 3070              3071            Yes  Air Miles    Postcard          Low
# 3108              3109             No  Air Miles      Letter          Low
# 3789              3790             No  Air Miles      Letter       Medium
# 5083              5084             No     Points      Letter       Medium
# 5677              5678             No  Air Miles    Postcard          Low
# 5689              5690             No  Air Miles    Postcard       Medium
# 6932              6933             No  Air Miles    Postcard       Medium
# 7787              7788             No  Air Miles      Letter          Low
# 7864              7865             No  Cash Back    Postcard         High
# 8151              8152             No  Cash Back      Letter          Low
# 8634              8635             No  Air Miles    Postcard         High
# ...

# %%
df[df.isna().any(axis=1)].count()
# Out:
# Customer Number         24
# Offer Accepted          24
# Reward                  24
# Mailer Type             24
# Income Level            24
# # Bank Accounts Open    24
# Overdraft Protection    24
# Credit Rating           24
# # Credit Cards Held     24
# # Homes Owned           24
# Household Size          24
# Own Your Home           24
# Average Balance          0
# Q1 Balance               0
# Q2 Balance               0
# Q3 Balance               0
# Q4 Balance               0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %%
df.drop(['Customer Number'],axis=1,inplace=True)

# %%
df
# Out:
#       Offer Accepted     Reward Mailer Type Income Level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17995             No  Cash Back      Letter         High
# 17996             No  Cash Back      Letter         High
# 17997             No  Cash Back      Letter         High
# 17998             No  Cash Back      Letter       Medium
# 17999             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %% [markdown]
# # change target from yes/no to 1/0

# %%
new_int = []
for i in df['Offer Accepted']:
    if i == 'No':
        new_int.append(0)
    else:
        new_int.append(1)
df['Offer Accepted']=new_int
df
# Out:
#        Offer Accepted     Reward Mailer Type Income Level  \
# 0                   0  Air Miles      Letter         High
# 1                   0  Air Miles      Letter       Medium
# 2                   0  Air Miles    Postcard         High
# 3                   0  Air Miles      Letter       Medium
# 4                   0  Air Miles      Letter       Medium
# ...               ...        ...         ...          ...
# 17995               0  Cash Back      Letter         High
# 17996               0  Cash Back      Letter         High
# 17997               0  Cash Back      Letter         High
# 17998               0  Cash Back      Letter       Medium
# 17999               0  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %% [markdown]
# # change column name(original is hard to work with)

# %%
df.columns
# Out:
# Index(['Offer Accepted', 'Reward', 'Mailer Type', 'Income Level',
#        '# Bank Accounts Open', 'Overdraft Protection', 'Credit Rating',
#        '# Credit Cards Held', '# Homes Owned', 'Household Size',
#        'Own Your Home', 'Average Balance', 'Q1 Balance', 'Q2 Balance',
#        'Q3 Balance', 'Q4 Balance'],
#       dtype='object')

# %%
df.columns = ['Offer_Accepted', 'Reward', 'Mailer_Type', 'Income_Level',
       'Bank_Accnt_Open', 'Overdraft_Protection', 'Credit_Rating',
       'Credit_Cards_Held', 'Homes_Owned', 'Household_Size',
       'Own_Your_Home', 'Average_Balance', 'Q1_Balance', 'Q2_Balance',
       'Q3_Balance', 'Q4_Balance']

# %%
df
# Out:
#        Offer_Accepted     Reward Mailer_Type Income_Level  Bank_Accnt_Open  \
# 0                   0  Air Miles      Letter         High                1
# 1                   0  Air Miles      Letter       Medium                1
# 2                   0  Air Miles    Postcard         High                2
# 3                   0  Air Miles      Letter       Medium                2
# 4                   0  Air Miles      Letter       Medium                1
# ...               ...        ...         ...          ...              ...
# 17995               0  Cash Back      Letter         High                1
# 17996               0  Cash Back      Letter         High                1
# 17997               0  Cash Back      Letter         High                1
# 17998               0  Cash Back      Letter       Medium                1
# 17999               0  Cash Back      Letter          Low                2
#
# ...

# %% [markdown]
# # change credit rating

# %%
df['Credit_Rating'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
listx = []
for i in df['Credit_Rating']:
    if i == 'High':
        listx.append(3)
    elif i=='Medium':
        listx.append(2)
    else:
        listx.append(1)
df['Credit_Rating']=listx
df
# Out:
#        Offer_Accepted     Reward Mailer_Type Income_Level  Bank_Accnt_Open  \
# 0                   0  Air Miles      Letter         High                1
# 1                   0  Air Miles      Letter       Medium                1
# 2                   0  Air Miles    Postcard         High                2
# 3                   0  Air Miles      Letter       Medium                2
# 4                   0  Air Miles      Letter       Medium                1
# ...               ...        ...         ...          ...              ...
# 17995               0  Cash Back      Letter         High                1
# 17996               0  Cash Back      Letter         High                1
# 17997               0  Cash Back      Letter         High                1
# 17998               0  Cash Back      Letter       Medium                1
# 17999               0  Cash Back      Letter          Low                2
#
# ...

# %% [markdown]
# # export clean dataset to csv file

# %%
df.to_csv('CreditCardDataset_cleaned.csv',index=False)

# %%
dfx= pd.read_csv('CreditCardDataset_cleaned.csv')
dfx
# Out:
#        Offer_Accepted     Reward Mailer_Type Income_Level  Bank_Accnt_Open  \
# 0                   0  Air Miles      Letter         High                1
# 1                   0  Air Miles      Letter       Medium                1
# 2                   0  Air Miles    Postcard         High                2
# 3                   0  Air Miles      Letter       Medium                2
# 4                   0  Air Miles      Letter       Medium                1
# ...               ...        ...         ...          ...              ...
# 17971               0  Cash Back      Letter         High                1
# 17972               0  Cash Back      Letter         High                1
# 17973               0  Cash Back      Letter         High                1
# 17974               0  Cash Back      Letter       Medium                1
# 17975               0  Cash Back      Letter          Low                2
#
# ...
